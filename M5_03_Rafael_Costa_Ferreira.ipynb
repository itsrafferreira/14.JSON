# %% [markdown]
# # Exercicios Modulo 5. JSON (Soluções)
#
# Considerações a ter em conta:
#
# * Guardar odocumento de soluções comoseguinte formatopara entrega: __M2_01_nome_apelido1_apelido2__
# * Realizar os exercicios com as ferramentas utilizadas nas aulas.
# * Comentar o código
# * Utilizar nomesde variáveis apropriados. Se vamosguardar umanota, chamamos a essa variável nota, não n oux.

# %% [markdown]
# # JSON (JavaScript Object Notation)

# %% [markdown]
# 1) Tenha em consideração o seguinte JSON String:
#
# {"chefe_projeto":{"Nome":"Juan","Idade":28,"Experiência": ["Gestão","Finanças","Basesdedados"],"Residência":
# "Madrid","HorasProjeto":3500},"funcionários":[{"Nome":"Elena","Idade":26,"Experiência":
# ["JavaScript","Python"],"Residência":"Madrid","HorasProjeto":500},{"Nome":"Luis","Idade":31,"Experiência":
# ["Django","Flask","Pyramid"],"Residência":"Barcelona","HorasProjeto":1100}]}
#
#
# * Se necessário, utilizar um visualizador de JSON para o entender.
# * O objetivo é criar um dicionário com todos os dados e estruturas internas necessárias para que seja igual ao JSON String.
# * Criar estruturas mais pequenas até que se chegue a formar o mesmo JSON string que vemos acima.
# * Armazenar esta estrutura (o dicionário) numa variável.
# * Comprovar o seu tipo e mostrar por ecrã.
# * Criar duas variáveis: horas_funcionários e horas_chefe
# * Extrair as horas do chefe e introduzir na sua variável.
# * Criar um ciclo que percorra a totalidade de funcionários que tem na estrutura e para cada funcionário somar as suas horas na sua variável correspondente.
# * Somar todas as horas e imprimir.

# %%
import json

# JSON String fornecido
json_string = '{"chefe_projeto":{"Nome":"Juan","Idade":28,"Experiência": ["Gestão","Finanças","Basesdedados"],"Residência": "Madrid","HorasProjeto":3500},"funcionários":[{"Nome":"Elena","Idade":26,"Experiência": ["JavaScript","Python"],"Residência":"Madrid","HorasProjeto":500},{"Nome":"Luis","Idade":31,"Experiência": ["Django","Flask","Pyramid"],"Residência":"Barcelona","HorasProjeto":1100}]}'

# Converter JSON String para dicionário
dados = json.loads(json_string)

# Exibir o tipo da variável
print("Tipo da variável 'dados':", type(dados))

# Criar duas variáveis para armazenar as horas dos funcionários e do chefe
horas_funcionarios = 0
horas_chefe = dados['chefe_projeto']['HorasProjeto']

# Calcular e somar as horas dos funcionários
for funcionario in dados['funcionários']:
    horas_funcionarios += funcionario['HorasProjeto']

# Somar todas as horas
total_horas = horas_chefe + horas_funcionarios

# Exibir o resultado
print("\nHoras do chefe:", horas_chefe)
print("Horas dos funcionários:", horas_funcionarios)
print("Total de horas:", total_horas)
# Out:
# Tipo da variável 'dados': <class 'dict'>
#
# Horas do chefe: 3500
# Horas dos funcionários: 1600
# Total de horas: 5100

# %% [markdown]
# 2) No exercício anterior trabalhou-se com um dicionário que nós mesmos/as criamos. Converter para um formato JSON String, imprimir o seu tipo e os seus dados. Para que serve este formato?

# %%
O formato JSON é útil para a comunicação entre sistemas, especialmente em serviços web, onde é comum enviar e receber dados nesse formato. Ele é fácil de entender, eficiente em termos de espaço e pode ser facilmente convertido para estruturas de dados em várias linguagens de programação. Além disso, muitas APIs e serviços web utilizam JSON como o formato padrão para troca de dados.

# %% [markdown]
# 3) Por vezes encontramos JSON que se tem de modificar. Para isso, temos de descodificá-los, fazer as modificações pertinentes e voltar a codificá-los para os deixar como JSON de novo. No seguinte exemplo podemos ver que há alguns erros:
#
# * Ao Superman falta-lhe como poder "Voar"
# * No Batman, a idade é 35, não 350
# * No Batman, retire-lhe o poder de "Raio laser"
# * No Wonder Woman falta-lhe o poder "Laço da verdade"
#
# Depois de corrigir, sem criar um novo, voltar a transformar estes dados num JSON String

# %%
# NÃO UTILIZE ESTE BLOCO

superherois = {
	"nomedaEquipa": "Super Hero Squad",
	"cidade": "Metro City",
	"formado": 2016,
	"baseSecreta": "Super Tower",
	"activo": "Sim",
	"membros": [
		{
			"nome": "SuperMan",
			"idade": 29,
			"identidadeSecreta": "Clart Kent",
			"poderes": [
				"Super força",
				"Super velocidade",
				"Raio laser"
			]
		},
		{
			"nome": "Batman",
			"idade": 350,
			"identidadeSecreta": "Bruce Wayne",
			"poderes": [
				"Detective",
				"Dinheiro",
				"Raio laser"
			]
		},
		{
			"nome": "Wonder Woman",
			"idade": 900,
			"identidadeSecreta": "Diana de Temiscira",
			"poderes": [
				"Super força",
				"Super velocidade"
			]
		}
	]
}

# %%
import json

# Dados corrigidos
superherois = {
    "nomedaEquipa": "Super Hero Squad",
    "cidade": "Metro City",
    "formado": 2016,
    "baseSecreta": "Super Tower",
    "activo": "Sim",
    "membros": [
        {
            "nome": "Superman",
            "idade": 29,
            "identidadeSecreta": "Clark Kent",
            "poderes": [
                "Super forca",
                "Super velocidade",
                "Voar"  # Adicionado o poder "Voar"
            ]
        },
        {
            "nome": "Batman",
            "idade": 35,  # Corrigida a idade de 350 para 35
            "identidadeSecreta": "Bruce Wayne",
            "poderes": [
                "Detective",
                "Dinheiro"
            ]  # Removido o poder "Raio laser"
        },
        {
            "nome": "Wonder Woman",
            "idade": 900,
            "identidadeSecreta": "Diana de Temiscira",
            "poderes": [
                "Super forca",
                "Super velocidade",
                "Laco da verdade"  # Adicionado o poder "Laço da verdade"
            ]
        }
    ]
}

# Transformar os dados corrigidos em JSON String
superherois_json = json.dumps(superherois, indent=2)  # indent para formatar a string com indentação

# Exibir a JSON String resultante
print(superherois_json)
# Out:
# {
#   "nomedaEquipa": "Super Hero Squad",
#   "cidade": "Metro City",
#   "formado": 2016,
#   "baseSecreta": "Super Tower",
#   "activo": "Sim",
#   "membros": [
#     {
#       "nome": "Superman",
#       "idade": 29,
#       "identidadeSecreta": "Clark Kent",
#       "poderes": [
#         "Super forca",
#         "Super velocidade",
#         "Voar"
#       ]
#     },
#     {
#       "nome": "Batman",
#       "idade": 35,
#       "identidadeSecreta": "Bruce Wayne",
#       "poderes": [
#         "Detective",
#         "Dinheiro"
#       ]
#     },
#     {
#       "nome": "Wonder Woman",
#       "idade": 900,
#       "identidadeSecreta": "Diana de Temiscira",
#       "poderes": [
#         "Super forca",
#         "Super velocidade",
#         "Laco da verdade"
#       ]
#     }
#   ]
# }

# %% [markdown]
# 4) Com base no exercício anterior, modificar a estrutura de **super_herois** para conseguir que **membros** tenham dois ramos: "membrosAtivos" e "membrosInativos", onde cada um destes ramos, armazenem os heróis que estão no ativo e os que não. Neste caso, introduzimos SuperMan e WonderWoman na lista de ativos e Batman na de inativos. Esta modificação podemos fazê-la como quisermos: ou programando as estruturas de dados e adicionar ao JSON ou fazer a alteração diretamente no JSON. Ao finalizar, podemos comprovar o nosso JSON num visualizador online.(http://jsonviewer.stack.hu/)

# %%
import json

# Dados corrigidos e modificados
superherois = {
    "nomedaEquipa": "Super Hero Squad",
    "cidade": "Metro City",
    "formado": 2016,
    "baseSecreta": "Super Tower",
    "activo": "Sim",
    "membros": {
        "membrosAtivos": [
            {
                "nome": "Superman",
                "idade": 29,
                "identidadeSecreta": "Clark Kent",
                "poderes": ["Super forca", "Super velocidade", "Voar"]
            },
            {
                "nome": "Wonder Woman",
                "idade": 900,
                "identidadeSecreta": "Diana de Temiscira",
                "poderes": ["Super forca", "Super velocidade", "Laco da verdade"]
            }
        ],
        "membrosInativos": [
            {
                "nome": "Batman",
                "idade": 35,
                "identidadeSecreta": "Bruce Wayne",
                "poderes": ["Detective", "Dinheiro"]
            }
        ]
    }
}

# Transformar os dados modificados em JSON String
superherois_json = json.dumps(superherois, indent=2)

# Exibir a JSON String resultante
print(superherois_json)
# Out:
# {
#   "nomedaEquipa": "Super Hero Squad",
#   "cidade": "Metro City",
#   "formado": 2016,
#   "baseSecreta": "Super Tower",
#   "activo": "Sim",
#   "membros": {
#     "membrosAtivos": [
#       {
#         "nome": "Superman",
#         "idade": 29,
#         "identidadeSecreta": "Clark Kent",
#         "poderes": [
#           "Super forca",
#           "Super velocidade",
#           "Voar"
#         ]
#       },
#       {
#         "nome": "Wonder Woman",
#         "idade": 900,
#         "identidadeSecreta": "Diana de Temiscira",
#         "poderes": [
#           "Super forca",
#           "Super velocidade",
#           "Laco da verdade"
#         ]
#       }
#     ],
#     "membrosInativos": [
#       {
#         "nome": "Batman",
#         "idade": 35,
#         "identidadeSecreta": "Bruce Wayne",
#         "poderes": [
#           "Detective",
#           "Dinheiro"
#         ]
#       }
#     ]
#   }
# }

# %% [markdown]
# 5) No seguinte código, aceder a um JSON de forma remota. A partir da resposta, fazer o seguinte:
#
# * Mostrar o tipo de dados que se recebeu.
# * Expor os dados recebidos.
# * Mostrar o número de pessoas que se encontram atualmente na estrutura.
# * Fazer um ciclo que percorra todas essas pessoas e mostre os seus detalhes (nome, armazém, etc) no qual  se encontra.

# %%
from pip._vendor import requests


# API que nos comunica quantas pessoas se encontram atualmente no espaço 
response = requests.get("http://api.open-notify.org/astros.json")
data = response.json()

import requests

# API que nos comunica quantas pessoas se encontram atualmente no espaço 
response = requests.get("http://api.open-notify.org/astros.json")

# Verificar se a requisição foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Mostrar o tipo de dados que foi recebido
    print("Tipo de dados recebidos:", type(response.json()))

    # Expor os dados recebidos
    print("\nDados recebidos:")
    print(response.json())

    # Mostrar o número de pessoas na estrutura
    numero_de_pessoas = data["number"]
    print("\nNúmero de pessoas no espaço:", numero_de_pessoas)

    # Fazer um ciclo que percorra todas essas pessoas e mostre os seus detalhes
    pessoas = data["people"]
    print("\nDetalhes das pessoas no espaço:")
    for pessoa in pessoas:
        print(f"Nome: {pessoa['name']}, Nave: {pessoa['craft']}")
else:
    print("Erro na requisição. Código de status:", response.status_code)
# Out:
# Tipo de dados recebidos: <class 'dict'>
#
# Dados recebidos:
# {'message': 'success', 'people': [{'name': 'Jasmin Moghbeli', 'craft': 'ISS'}, {'name': 'Andreas Mogensen', 'craft': 'ISS'}, {'name': 'Satoshi Furukawa', 'craft': 'ISS'}, {'name': 'Konstantin Borisov', 'craft': 'ISS'}, {'name': 'Oleg Kononenko', 'craft': 'ISS'}, {'name': 'Nikolai Chub', 'craft': 'ISS'}, {'name': "Loral O'Hara", 'craft': 'ISS'}], 'number': 7}
#
# Número de pessoas no espaço: 7
#
# Detalhes das pessoas no espaço:
# Nome: Jasmin Moghbeli, Nave: ISS
# Nome: Andreas Mogensen, Nave: ISS
# Nome: Satoshi Furukawa, Nave: ISS
# Nome: Konstantin Borisov, Nave: ISS
# Nome: Oleg Kononenko, Nave: ISS
# Nome: Nikolai Chub, Nave: ISS
# Nome: Loral O'Hara, Nave: ISS
